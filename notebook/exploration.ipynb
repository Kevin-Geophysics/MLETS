# %% [markdown]
# # MT-HDBSCAN — Permeable Pathway Detection
# Notebook eksplorasi. Pipeline utama dijalankan lewat `main.py`.

# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))  # root project

from src import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. Konfigurasi
# Sesuaikan path dan parameter di sini sebelum jalan.

# %%
from main import CONFIG, run_pipeline

# Override config kalau perlu, misal:
# CONFIG["slice_y_coord"] = 4263000.0
# CONFIG["min_cluster_size"] = 50

# %% [markdown]
# ## 2. Jalankan Full Pipeline

# %%
results = run_pipeline(CONFIG)

df_mt        = results["df_mt"]
df_eq        = results["df_eq"]
df_well_log  = results["df_well_log"]
df_well_traj = results["df_well_traj"]
stats        = results["stats"]

# %% [markdown]
# ## 3. Eksplorasi Hasil Clustering

# %%
# Distribusi label klaster
print(df_mt["cluster_labels"].value_counts().sort_index())

# %%
# Statistik validasi sumur vs P21
stats

# %% [markdown]
# ## 4. Plot Slice Tambahan
# Ganti `slice_y_coord` untuk eksplorasi penampang lain.

# %%
fig = plot_2d_slice_with_eq(
    df_mt, df_eq,
    df_well_trajectory=df_well_traj,
    slice_coord=CONFIG["slice_y_coord"],
    tolerance=100,                        # perlebar kalau well tidak muncul
    global_mag_min=df_eq["magnitude"].min(),
)
plt.show()
